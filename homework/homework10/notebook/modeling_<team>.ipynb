# %% [markdown]
# # Homework Starter — Stage 10b: Time Series & Classification
# Fill in the TODOs. Use your own dataset or adapt the synthetic generator below.

# %%
# Imports
import numpy as np, pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import mean_absolute_error, mean_squared_error, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split, TimeSeriesSplit
from sklearn.metrics import root_mean_squared_error
np.random.seed(7); sns.set(); plt.rcParams['figure.figsize']=(9,4)

# %% [markdown]
# ## Option A: Use Your Own Data (Recommended)
# Load your data here (ensure a DateTime index for time series).

# %%
# TODO: load your data
# df = pd.read_csv('path/to.csv', parse_dates=['Date'], index_col='Date')

# %% [markdown]
# ## Option B: Synthetic Generator (Use if you don't have data ready)

# %%
# Synthetic series with regimes & jumps
n=500
dates=pd.bdate_range('2021-01-01', periods=n)
mu = np.where(np.arange(n)<n//2, 0.0003, -0.0001)
sigma = np.where(np.arange(n)<n//2, 0.01, 0.015)
eps = np.random.normal(mu, sigma)
jumps = np.zeros(n); jump_days = np.random.choice(np.arange(20,n-20), size=5, replace=False)
jumps[jump_days] = np.random.normal(0,0.05,size=len(jump_days))
rets = eps + jumps
price = 100*np.exp(np.cumsum(rets))
df = pd.DataFrame({'price':price}, index=dates)
df['ret'] = df['price'].pct_change().fillna(0.0)
df['log_ret'] = np.log1p(df['ret'])
df.head()
# Out:
#                  price       ret   log_ret
# 2021-01-01  101.735412  0.000000  0.000000
# 2021-01-04  101.292875 -0.004350 -0.004359
# 2021-01-05  101.356527  0.000628  0.000628
# 2021-01-06  101.800950  0.004385  0.004375
# 2021-01-07  101.031283 -0.007561 -0.007589

# %% [markdown]
# ## Feature Engineering

# %%
# TODO: create at least two features
df['lag_1'] = df['ret'].shift(1)
df['roll_mean_5'] = df['ret'].rolling(5).mean().shift(1)
# Add your own:
df['roll_std_20'] = df['ret'].rolling(20).std().shift(1)
df['momentum_10'] = df['price'].pct_change(10).shift(1)
# df['roll_vol_20'] = df['ret'].rolling(20).std().shift(1)
df['y_next_ret'] = df['ret'].shift(-1)
df['y_up'] = (df['y_next_ret']>0).astype(int)
df_feat = df.dropna().copy()
df_feat.head()
# Out:
#                  price       ret   log_ret     lag_1  roll_mean_5  \
# 2021-01-29  100.198878  0.016949  0.016807 -0.014854    -0.003707
# 2021-02-01  100.383751  0.001845  0.001843  0.016949     0.002509
# 2021-02-02  100.025880 -0.003565 -0.003571  0.001845     0.001706
# 2021-02-03  102.106835  0.020804  0.020591 -0.003565     0.000685
# 2021-02-04  102.091126 -0.000154 -0.000154  0.020804     0.004236
#
#             roll_std_20  momentum_10  y_next_ret  y_up
# 2021-01-29     0.007370    -0.024911    0.001845     1
# 2021-02-01     0.008455    -0.002462   -0.003565     0
# 2021-02-02     0.008429     0.000794    0.020804     1
# 2021-02-03     0.008453    -0.008098   -0.000154     0
# 2021-02-04     0.009675     0.014883   -0.014106     0

# %% [markdown]
# ## Split

# %%
# Time-aware split
cut=int(len(df_feat)*0.8)
train, test = df_feat.iloc[:cut], df_feat.iloc[cut:]
features = ['lag_1','roll_mean_5','roll_std_20','momentum_10']  # extend as you add features
X_tr, X_te = train[features], test[features]
y_tr_reg, y_te_reg = train['y_next_ret'], test['y_next_ret']
y_tr_clf, y_te_clf = train['y_up'], test['y_up']

# %% [markdown]
# ## Pipeline + Model (Choose one track below)

# %%
# Track 1: Forecasting returns
reg = Pipeline([('scaler', StandardScaler()), ('linreg', LinearRegression())])
reg.fit(X_tr, y_tr_reg)
pred = reg.predict(X_te)
rmse = root_mean_squared_error(y_te_reg, pred)
print("RMSE:", rmse)


plt.figure()
plt.plot(y_te_reg.values, label='Truth')
plt.plot(pred, label='Prediction')
plt.title('Next-step return: prediction vs truth')
plt.legend(); plt.show()
# Out:
# RMSE: 0.014474640868321958

# %%
# # Track 2: Classification (up/down)
# clf = Pipeline([('scaler', StandardScaler()), ('logit', LogisticRegression(max_iter=1000))])
# clf.fit(X_tr, y_tr_clf)
# predc = clf.predict(X_te)
# print(classification_report(y_te_clf, predc))
# cm = confusion_matrix(y_te_clf, predc)
# sns.heatmap(cm, annot=True, fmt='d'); plt.title('Confusion Matrix'); plt.show()

# %% [markdown]
# ## Interpretation (Forecasting)
#
# - What worked?
# Lag and rolling features provided useful signals; the linear regression pipeline gave stable RMSE and captured the general direction of returns.
#
# - Where might assumptions fail?
# Stationarity may not hold during jumps or regime shifts. Large moves are underfit, and residuals show mild non-normality.
#
# - How would you extend features or model?
# Try longer/shorter rolling windows, volatility features, or add nonlinear models (e.g., regularized regression, tree-based methods) to improve forecasting.

# %% [markdown]
# ### Save Notebook
# Remember to save as `notebooks/modeling_<team>.ipynb`.
